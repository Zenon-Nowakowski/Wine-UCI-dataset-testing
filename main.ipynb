# %% [markdown]
# # Step 0
# First to install all dependencies and test to make sure the Wine dataset is functioning using provided code snippet in docs

# %%
from ucimlrepo import fetch_ucirepo
import pandas as pd 
import numpy as np

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
wine = fetch_ucirepo(id=109) 
  
# data (as pandas dataframes) 
datadf = wine.data.features 
classsdf = wine.data.targets 
# merge the 2 dataframes 
winedf = pd.merge(datadf,classsdf, left_index=True, right_index=True)

# metadata 
#print(wine.metadata) 
  
# variable information 
#print(wine.variables)

# %% [markdown]
# # Step 1:
# ## Read the data into a pandas data frame. Be sure to include headers for each of the fields
# this was already done in step 0 as the provided documentation code already had defined us some dataframes

# %%
winedf.head()
# Out:
#    Alcohol  Malicacid   Ash  Alcalinity_of_ash  Magnesium  Total_phenols  \
# 0    14.23       1.71  2.43               15.6        127           2.80
# 1    13.20       1.78  2.14               11.2        100           2.65
# 2    13.16       2.36  2.67               18.6        101           2.80
# 3    14.37       1.95  2.50               16.8        113           3.85
# 4    13.24       2.59  2.87               21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_phenols  Proanthocyanins  Color_intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    0D280_0D315_of_diluted_wines  Proline  class
# ...

# %%
#not sure why this is a seperate data frame?
targetsdf.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\zenon\Documents\GitHub\Wine-UCI-dataset-testing\main.ipynb Cell 6 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/zenon/Documents/GitHub/Wine-UCI-dataset-testing/main.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> #not sure why this is a seperate data frame?
# ----> <a href='vscode-notebook-cell:/c%3A/Users/zenon/Documents/GitHub/Wine-UCI-dataset-testing/main.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> targetsdf.head()
#
# NameError: name 'targetsdf' is not defined

# %% [markdown]
# # Step 2:
# ## Summarize the data with mean, std, max, and min values for each feature

# %%
winedf.mean()
# Out:
# Alcohol                          13.000618
# Malicacid                         2.336348
# Ash                               2.366517
# Alcalinity_of_ash                19.494944
# Magnesium                        99.741573
# Total_phenols                     2.295112
# Flavanoids                        2.029270
# Nonflavanoid_phenols              0.361854
# Proanthocyanins                   1.590899
# Color_intensity                   5.058090
# Hue                               0.957449
# 0D280_0D315_of_diluted_wines      2.611685
# Proline                         746.893258
# class                             1.938202
# dtype: float64

# %%
winedf.std()
# Out:
# Alcohol                           0.811827
# Malicacid                         1.117146
# Ash                               0.274344
# Alcalinity_of_ash                 3.339564
# Magnesium                        14.282484
# Total_phenols                     0.625851
# Flavanoids                        0.998859
# Nonflavanoid_phenols              0.124453
# Proanthocyanins                   0.572359
# Color_intensity                   2.318286
# Hue                               0.228572
# 0D280_0D315_of_diluted_wines      0.709990
# Proline                         314.907474
# class                             0.775035
# dtype: float64

# %%
winedf.max()
# Out:
# Alcohol                           14.83
# Malicacid                          5.80
# Ash                                3.23
# Alcalinity_of_ash                 30.00
# Magnesium                        162.00
# Total_phenols                      3.88
# Flavanoids                         5.08
# Nonflavanoid_phenols               0.66
# Proanthocyanins                    3.58
# Color_intensity                   13.00
# Hue                                1.71
# 0D280_0D315_of_diluted_wines       4.00
# Proline                         1680.00
# class                              3.00
# dtype: float64

# %%
winedf.min()
# Out:
# Alcohol                          11.03
# Malicacid                         0.74
# Ash                               1.36
# Alcalinity_of_ash                10.60
# Magnesium                        70.00
# Total_phenols                     0.98
# Flavanoids                        0.34
# Nonflavanoid_phenols              0.13
# Proanthocyanins                   0.41
# Color_intensity                   1.28
# Hue                               0.48
# 0D280_0D315_of_diluted_wines      1.27
# Proline                         278.00
# class                             1.00
# dtype: float64

# %% [markdown]
# # Step 3:
# ## Compute the correlation coefficients for each variable

# %%
winedf.corr()
# Out:
#                                Alcohol  Malicacid       Ash  \
# Alcohol                       1.000000   0.094397  0.211545
# Malicacid                     0.094397   1.000000  0.164045
# Ash                           0.211545   0.164045  1.000000
# Alcalinity_of_ash            -0.310235   0.288500  0.443367
# Magnesium                     0.270798  -0.054575  0.286587
# Total_phenols                 0.289101  -0.335167  0.128980
# Flavanoids                    0.236815  -0.411007  0.115077
# Nonflavanoid_phenols         -0.155929   0.292977  0.186230
# Proanthocyanins               0.136698  -0.220746  0.009652
# Color_intensity               0.546364   0.248985  0.258887
# Hue                          -0.071747  -0.561296 -0.074667
# 0D280_0D315_of_diluted_wines  0.072343  -0.368710  0.003911
# Proline                       0.643720  -0.192011  0.223626
# class                        -0.328222   0.437776 -0.049643
#
# ...

# %% [markdown]
# # Step 4:
# ## List the number of examples per class, and the number of missing features

# %%
#groupby classes and see how much data exists per class 
winedf.groupby(["class"]).count()
# Out:
#        Alcohol  Malicacid  Ash  Alcalinity_of_ash  Magnesium  Total_phenols  \
# class
# 1           59         59   59                 59         59             59
# 2           71         71   71                 71         71             71
# 3           48         48   48                 48         48             48
#
#        Flavanoids  Nonflavanoid_phenols  Proanthocyanins  Color_intensity  \
# class
# 1              59                    59               59               59
# 2              71                    71               71               71
# 3              48                    48               48               48
#
#        Hue  0D280_0D315_of_diluted_wines  Proline
# class
# 1       59                            59       59
# 2       71                            71       71
# 3       48                            48       48

# %%
# number of missing features 
winedf.isna().sum()
# Out:
# Alcohol                         0
# Malicacid                       0
# Ash                             0
# Alcalinity_of_ash               0
# Magnesium                       0
# Total_phenols                   0
# Flavanoids                      0
# Nonflavanoid_phenols            0
# Proanthocyanins                 0
# Color_intensity                 0
# Hue                             0
# 0D280_0D315_of_diluted_wines    0
# Proline                         0
# class                           0
# dtype: int64

# %% [markdown]
# # Step 5:
# ## Reduce the data to just the color intensity and hue columns, and save those data out as a tab-delimited file

# %%
winedf[['Color_intensity','Hue']].to_csv(path_or_buf="color_and_hue.csv", sep='\t')

# %% [markdown]
# # What types of problems is the data suitable for?
# Since the data is classified and has both large and small corolations within the dataset. Training a wine tasting bot which is able to tell classification or alcohol content based on another variable.
# # Pick a paper that references this data set (look at the linked website for examples). Read the paper and provide me with a one paragraph summary. Don't just copy the abstract.
# While there are plenty of papers which cite the data, 131 as of 10/1/2023, A Study of Fuzzy and Non-fuzzy clustering algorithms on Wine Data appears to be one of the few which activily uses the data as a central part of its paper. The paper tests different classifications algorithms and then displays the results of accuracy for each algorithm. The results indicate that class 1 is the easiest to distinguish while class 3 is the hardest. Except in the case of K-means which under performed everywere aside from class 2 identification, where it excelled. The rest of the data however, interestingly enough, repeats. The data is so similar it almost looks like my lab reports in 7th grade. Unlike me however they have graphs which proved they actually did their work. While the graphs are nearly identical, aside from color representation, the points are almost identical but have very tiny discrepencies if you stare at it long enough.
#
# ![Alt text](image.png)
#
# https://www.semanticscholar.org/reader/871a758b35b64a1dac839381d85f6a1afed9b2b3
